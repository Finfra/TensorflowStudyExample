# %% [markdown]
# # 6. RNN

# %% [markdown]
# ### Recurrent Neural Networks
# RNN은 자기자신을 향하는 weight를 이용해 데이터간의 시간관계를 학습할 수 있다. 이러한 문제들을 시계열 학습이라고 부르며, 기존에 널리 쓰이던 Hidden Markov Model을 뉴럴넷을 이용해 구현했다고 볼 수 있다.

# %% [markdown]
# ## 필요 라이브러리

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %% [markdown]
# ## 데이터 예시 세팅
# x　　y<br>
# 123　4<br>
# 234　5<br>
# 345　6<br>
# 456　7<br>
# 다음 수를 예측할 수 있는 모델을 목표로 하는 데이터 세팅

# %%
x = array([[1,2,3], [2,3,4], [3,4,5], [4,5,6], [5,6,7]])
y = array([4,5,6,7,8])

print('x shape : ', x.shape) # (4,3)
print('y shape : ', y.shape) # (4,)
# Out:
# x shape :  (5, 3)
# y shape :  (5,)

# %% [markdown]
# RNN 모델에 맞게 Reshape

# %%
x = x.reshape((x.shape[0], x.shape[1], 1)) # (4,3,1) reshape 전체 곱 수 같아야 4*3=4*3*1
print('x shape : ', x.shape)
print(x)
# Out:
# x shape :  (5, 3, 1)
# [[[1]
#   [2]
#   [3]]
#
#  [[2]
#   [3]
#   [4]]
#
#  [[3]
#   [4]
#   [5]]
#
#  [[4]
#   [5]
#   [6]]
#
#  [[5]
#   [6]
#   [7]]]

# %% [markdown]
# ## 모델 구성

# %%
model = Sequential()
model.add(LSTM(10, activation = 'relu', input_shape=(3,1)))
# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))
 
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10)                480
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 541
# Trainable params: 541
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델 학습 시키기

# %%
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 19s 5ms/step - loss: 57.6356
# Epoch 2/100
# 5/5 [==============================] - 0s 4ms/step - loss: 45.4685
# Epoch 3/100
# 5/5 [==============================] - 0s 4ms/step - loss: 37.9281
# Epoch 4/100
# 5/5 [==============================] - 0s 4ms/step - loss: 57.0165
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 38.2809
# Epoch 6/100
# 5/5 [==============================] - 0s 4ms/step - loss: 39.3277
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 56.0482
# Epoch 8/100
# 5/5 [==============================] - 0s 4ms/step - loss: 54.7432
# Epoch 9/100
# 5/5 [==============================] - 0s 4ms/step - loss: 49.9986
# Epoch 10/100
# 5/5 [==============================] - 0s 5ms/step - loss: 31.6676
# Epoch 11/100
# 5/5 [==============================] - 0s 4ms/step - loss: 32.9129
# Epoch 12/100
# 5/5 [==============================] - 0s 5ms/step - loss: 33.4844
# Epoch 13/100
# 5/5 [==============================] - 0s 4ms/step - loss: 44.7388
# Epoch 14/100
# 5/5 [==============================] - 0s 5ms/step - loss: 26.6110
# Epoch 15/100
# 5/5 [==============================] - 0s 4ms/step - loss: 27.5040
# Epoch 16/100
# 5/5 [==============================] - 0s 5ms/step - loss: 25.8231
# Epoch 17/100
# 5/5 [==============================] - 0s 5ms/step - loss: 32.1179
# Epoch 18/100
# 5/5 [==============================] - 0s 5ms/step - loss: 27.4978
# Epoch 19/100
# 5/5 [==============================] - 0s 4ms/step - loss: 24.1599
# Epoch 20/100
# 5/5 [==============================] - 0s 4ms/step - loss: 21.3119
# Epoch 21/100
# 5/5 [==============================] - 0s 4ms/step - loss: 17.4357
# Epoch 22/100
# 5/5 [==============================] - 0s 5ms/step - loss: 15.9402
# Epoch 23/100
# 5/5 [==============================] - 0s 5ms/step - loss: 15.1057
# Epoch 24/100
# 5/5 [==============================] - 0s 5ms/step - loss: 10.8499
# Epoch 25/100
# 5/5 [==============================] - 0s 4ms/step - loss: 8.2185
# Epoch 26/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.3051
# Epoch 27/100
# 5/5 [==============================] - 0s 4ms/step - loss: 3.8241
# Epoch 28/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.5105
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7534
# Epoch 30/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4965
# Epoch 31/100
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2303
# Epoch 32/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1522
# Epoch 33/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8274
# Epoch 34/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9845
# Epoch 35/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.3571
# Epoch 36/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6835
# Epoch 37/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0820
# Epoch 38/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2197
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7424
# Epoch 40/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9970
# Epoch 41/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5666
# Epoch 42/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5828
# Epoch 43/100
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1978
# Epoch 44/100
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1425
# Epoch 45/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7580
# Epoch 46/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7024
# Epoch 47/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5934
# Epoch 48/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5581
# Epoch 49/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9632
# Epoch 50/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4766
# Epoch 51/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7490
# Epoch 52/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6684
# Epoch 53/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6357
# Epoch 54/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7296
# Epoch 55/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4073
# Epoch 56/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8457
# Epoch 57/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5401
# Epoch 58/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7956
# Epoch 59/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3689
# Epoch 60/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6432
# Epoch 61/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4380
# Epoch 62/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5277
# Epoch 63/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7187
# Epoch 64/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3744
# Epoch 65/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5016
# Epoch 66/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6174
# Epoch 67/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3060
# Epoch 68/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6263
# Epoch 69/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4991
# Epoch 70/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3240
# Epoch 71/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5195
# Epoch 72/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3306
# Epoch 73/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5401
# Epoch 74/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2950
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5027
# Epoch 76/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4593
# Epoch 77/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5063
# Epoch 78/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5498
# Epoch 79/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3328
# Epoch 80/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2636
# Epoch 81/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2333
# Epoch 82/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2961
# Epoch 83/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4544
# Epoch 84/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2750
# Epoch 85/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4144
# Epoch 86/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2568
# Epoch 87/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2427
# Epoch 88/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3870
# Epoch 89/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2162
# Epoch 90/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2072
# Epoch 91/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1977
# Epoch 92/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2691
# Epoch 93/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1480
# Epoch 94/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1165
# Epoch 95/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2227
# Epoch 96/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1997
# Epoch 97/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1914
# Epoch 98/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1869
# Epoch 99/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1048
# Epoch 100/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1084

# %% [markdown]
# ## TEST

# %%
x_input = array([6,7,8])
x_input = x_input.reshape((1,3,1))

yhat = model.predict(x_input)
print(yhat)
# Out:
# [[9.514655]]

# %% [markdown]
# 출처: https://ebbnflow.tistory.com/135 [Dev Log : 삶은 확률의 구름]
