# %% [markdown]
# # 1. Kaggle에서 Data Load
# ## kaggle.json파일 다운로드 받는 방법
# * Kaggle.com에 회원가입 후
# * Upser Profile의 Account 탭에서 API항목에서 "Create New API Token" 클릭하면 다운로드 가능

# %%
# !pip uninstall kaggle
# Out:
# Uninstalling kaggle-1.5.4:
#   Would remove:
#     /usr/local/bin/kaggle
#     /usr/local/lib/python3.6/dist-packages/kaggle-1.5.4.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/kaggle/*
# Proceed (y/n)? y
#   Successfully uninstalled kaggle-1.5.4

# %%
# !x=$(pip list|grep kaggle);[ ${#x} -eq 0 ]&& pip install kaggle==1.5.10

import os

# Upload the API token.
def get_kaggle_credentials():
  token_dir = os.path.join(os.path.expanduser("~"),".kaggle")
  token_file = os.path.join(token_dir, "kaggle.json")
  if not os.path.isdir(token_dir):
    os.mkdir(token_dir)
  try:
    with open(token_file,'r') as f:
      pass
  except IOError as no_file:
    try:
      from google.colab import files
    except ImportError:
      raise no_file
    
    uploaded = files.upload()
    
    if "kaggle.json" not in uploaded:
      raise ValueError("You need an API key! see: "
                       "https://github.com/Kaggle/kaggle-api#api-credentials")
    with open(token_file, "wb") as f:
      f.write(uploaded["kaggle.json"])
    os.chmod(token_file, 600)

get_kaggle_credentials()
# Out:
#      <input type="file" id="files-4b07c60d-2f6f-4655-bef1-c4823f8bd921" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b07c60d-2f6f-4655-bef1-c4823f8bd921">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %% [markdown]
# # Kaggle Competition의 data를 받는 방법
# 1. 해당 Competition Page에 접속하여 "Join Competition" 클릭
# 2. Terminal 명령으로 Data File Dowmnload

# %%
#! tmux 
# !kaggle competitions download -c riiid-test-answer-prediction
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# competition.cpython-37m-x86_64-linux-gnu.so: Skipping, found more recently modified local copy (use --force to force download)
# __init__.py: Skipping, found more recently modified local copy (use --force to force download)
# questions.csv: Skipping, found more recently modified local copy (use --force to force download)
# lectures.csv: Skipping, found more recently modified local copy (use --force to force download)
# example_test.csv: Skipping, found more recently modified local copy (use --force to force download)
# example_sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls -lash
# Out:
# total 1.3G
# 4.0K drwxr-xr-x 1 root root 4.0K Feb  1 05:04  .
# 4.0K drwxr-xr-x 1 root root 4.0K Feb  1 05:01  ..
# 448K -rw-r--r-- 1 root root 445K Feb  1 05:04  competition.cpython-37m-x86_64-linux-gnu.so
# 4.0K drwxr-xr-x 1 root root 4.0K Jan 28 17:15  .config
# 4.0K -rw-r--r-- 1 root root  971 Feb  1 05:04  example_sample_submission.csv
# 8.0K -rw-r--r-- 1 root root 6.0K Feb  1 05:04  example_test.csv
# 4.0K -rw-r--r-- 1 root root   59 Feb  1 05:04  __init__.py
# 4.0K -rw-r--r-- 1 root root   65 Feb  1 05:03 'kaggle (1).json'
# 4.0K -rw-r--r-- 1 root root   65 Feb  1 05:04  kaggle.json
#  12K -rw-r--r-- 1 root root 9.5K Feb  1 05:04  lectures.csv
# 292K -rw-r--r-- 1 root root 290K Feb  1 05:04  questions.csv
# 4.0K drwxr-xr-x 1 root root 4.0K Jan 20 17:27  sample_data
# 1.3G -rw-r--r-- 1 root root 1.3G Feb  1 05:04  train.csv.zip

# %%
# !unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
# !ls -alsh |grep train
# Out:
# 5.5G -rw-r--r-- 1 root root 5.5G Oct 14 17:45 train.csv
# 1.3G -rw-r--r-- 1 root root 1.3G Feb  1 05:04 train.csv.zip

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            12G        526M        149M        1.0M         12G         11G
# Swap:            0B          0B          0B
