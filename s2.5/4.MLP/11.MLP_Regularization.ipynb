# %% [markdown]
# # 11. Regularization 적용해 보기
# * [딥러닝 용어 정리, L1 Regularization, L2 Regularization 의 이해, 용도와 차이 설명](https://light-tree.tistory.com/125)
# ---
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile4.uf.tistory.com%2Fimage%2F99BED3425CE4B1341814F6)

# %% [markdown]
# ## Hyper Parameter 설정

# %%
batch_size = 10
num_classes = 3
epochs = 200

# %% [markdown]
# ## 라이브러리 및 함수설정

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import optimizers

import matplotlib.pyplot as plt
def hist_view(hist):
  print('## training loss and acc ##')
  fig, loss_ax = plt.subplots()
  acc_ax = loss_ax.twinx()

  loss_ax.plot(hist.history['loss'], 'y', label='train loss')
  loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

  loss_ax.set_xlabel('epoch')
  loss_ax.set_ylabel('loss')
  loss_ax.legend(loc='center')

  acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
  acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
  acc_ax.set_ylabel('accuracy')
  acc_ax.legend(loc='center right')

  plt.show()

# %% [markdown]
# ## 데이터 로드

# %%
# from sklearn import datasets
# iris = datasets.load_iris()
# x=iris.data
import pandas as pd
![ ! -f  iris0.csv ]&&wget http://j.finfra.com/_file/iris0.csv
iris=pd.read_csv("iris0.csv")
# Out:
# --2021-08-09 05:46:07--  http://j.finfra.com/_file/iris0.csv
# Resolving j.finfra.com (j.finfra.com)... 211.252.85.187
# Connecting to j.finfra.com (j.finfra.com)|211.252.85.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3730 (3.6K) [text/csv]
# Saving to: ‘iris0.csv’
#
# iris0.csv           100%[===================>]   3.64K  --.-KB/s    in 0s
#
# 2021-08-09 05:46:08 (347 MB/s) - ‘iris0.csv’ saved [3730/3730]

# %% [markdown]
# ## input data 와 target data 설정

# %%
x=iris.iloc[:,0:4].values
y_text=iris.iloc[:,4:5]

sets=y_text.drop_duplicates()["Species"].tolist()
encoder={k:v for v,k in enumerate(sets)}
y_num=[ encoder[i] for i in y_text["Species"].tolist() ]

# %% [markdown]
# ## 훈련 데이터와 평가 데이터 분리

# %%
# iris.target → y
y= keras.utils.to_categorical(y_num, num_classes)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((105, 4), (45, 4), (105, 3), (45, 3))

# %% [markdown]
# ## Model 에 Regularization 적용

# %%
from keras.layers import BatchNormalization, Dropout
from keras import regularizers

l2=regularizers.l2(l2=0.01)

model = Sequential()

model.add(Dense(6, activation='relu', input_shape=(4,)))
model.add(Dense(4, activation='relu',kernel_regularizer=l2))

model.add(Dense(4, activation='relu',kernel_regularizer='l1'))

model.add(Dense(num_classes, activation='softmax'))
model.summary()

adam=optimizers.Adam(0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# batch_size,epochs
spe=int(x_train.shape[0]/batch_size )
hist=model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          steps_per_epoch=spe,
          validation_data=(x_test, y_test))

# help(model.fit)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 93
# Trainable params: 93
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 10/10 [==============================] - 3s 23ms/step - loss: 1.2265 - accuracy: 0.2900 - val_loss: 1.1728 - val_accuracy: 0.4000
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1892 - accuracy: 0.3158 - val_loss: 1.1594 - val_accuracy: 0.4000
# Epoch 3/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1762 - accuracy: 0.3263 - val_loss: 1.1496 - val_accuracy: 0.4000
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1694 - accuracy: 0.2842 - val_loss: 1.1412 - val_accuracy: 0.4000
# Epoch 5/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1476 - accuracy: 0.3053 - val_loss: 1.1336 - val_accuracy: 0.4000
# Epoch 6/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1376 - accuracy: 0.3158 - val_loss: 1.1252 - val_accuracy: 0.4444
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1281 - accuracy: 0.3368 - val_loss: 1.1083 - val_accuracy: 0.5111
# Epoch 8/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1022 - accuracy: 0.3263 - val_loss: 1.0751 - val_accuracy: 0.5111
# Epoch 9/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0584 - accuracy: 0.3789 - val_loss: 1.0420 - val_accuracy: 0.5333
# Epoch 10/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0344 - accuracy: 0.4000 - val_loss: 1.0313 - val_accuracy: 0.3556
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9928 - accuracy: 0.5158 - val_loss: 1.0227 - val_accuracy: 0.4444
# Epoch 12/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9790 - accuracy: 0.5700 - val_loss: 1.0128 - val_accuracy: 0.5111
# Epoch 13/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9734 - accuracy: 0.6000 - val_loss: 1.0039 - val_accuracy: 0.5556
# Epoch 14/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9523 - accuracy: 0.6211 - val_loss: 0.9944 - val_accuracy: 0.5556
# Epoch 15/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9262 - accuracy: 0.6632 - val_loss: 0.9882 - val_accuracy: 0.5556
# Epoch 16/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9358 - accuracy: 0.6000 - val_loss: 0.9807 - val_accuracy: 0.5556
# Epoch 17/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8876 - accuracy: 0.7263 - val_loss: 0.9715 - val_accuracy: 0.5778
# Epoch 18/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9203 - accuracy: 0.6421 - val_loss: 0.9632 - val_accuracy: 0.5778
# Epoch 19/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9088 - accuracy: 0.6316 - val_loss: 0.9517 - val_accuracy: 0.6000
# Epoch 20/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8837 - accuracy: 0.6842 - val_loss: 0.9433 - val_accuracy: 0.6000
# Epoch 21/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8722 - accuracy: 0.6632 - val_loss: 0.9325 - val_accuracy: 0.6000
# Epoch 22/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8661 - accuracy: 0.6842 - val_loss: 0.9214 - val_accuracy: 0.6000
# Epoch 23/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8543 - accuracy: 0.7000 - val_loss: 0.9138 - val_accuracy: 0.6000
# Epoch 24/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8536 - accuracy: 0.6632 - val_loss: 0.9045 - val_accuracy: 0.6000
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8240 - accuracy: 0.7158 - val_loss: 0.9026 - val_accuracy: 0.6000
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8573 - accuracy: 0.6737 - val_loss: 0.8899 - val_accuracy: 0.6000
# Epoch 27/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8389 - accuracy: 0.6526 - val_loss: 0.8804 - val_accuracy: 0.6000
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7990 - accuracy: 0.7368 - val_loss: 0.8739 - val_accuracy: 0.6000
# Epoch 29/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8080 - accuracy: 0.6842 - val_loss: 0.8677 - val_accuracy: 0.6000
# Epoch 30/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8284 - accuracy: 0.6421 - val_loss: 0.8609 - val_accuracy: 0.6000
# Epoch 31/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7898 - accuracy: 0.6947 - val_loss: 0.8502 - val_accuracy: 0.6000
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7820 - accuracy: 0.6947 - val_loss: 0.8465 - val_accuracy: 0.6000
# Epoch 33/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7877 - accuracy: 0.6842 - val_loss: 0.8356 - val_accuracy: 0.6000
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7749 - accuracy: 0.7000 - val_loss: 0.8253 - val_accuracy: 0.6000
# Epoch 35/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7519 - accuracy: 0.6632 - val_loss: 0.8182 - val_accuracy: 0.6000
# Epoch 36/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7470 - accuracy: 0.7053 - val_loss: 0.8107 - val_accuracy: 0.6000
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7605 - accuracy: 0.7053 - val_loss: 0.7934 - val_accuracy: 0.6000
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7596 - accuracy: 0.7474 - val_loss: 0.7754 - val_accuracy: 0.7333
# Epoch 39/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7265 - accuracy: 0.8000 - val_loss: 0.7695 - val_accuracy: 0.6444
# Epoch 40/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7090 - accuracy: 0.7684 - val_loss: 0.7649 - val_accuracy: 0.6000
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7275 - accuracy: 0.7158 - val_loss: 0.7532 - val_accuracy: 0.6000
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6759 - accuracy: 0.7789 - val_loss: 0.7425 - val_accuracy: 0.6000
# Epoch 43/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.7684 - val_loss: 0.7273 - val_accuracy: 0.6444
# Epoch 44/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6832 - accuracy: 0.7579 - val_loss: 0.7133 - val_accuracy: 0.6444
# Epoch 45/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.7900 - val_loss: 0.7035 - val_accuracy: 0.6444
# Epoch 46/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.8105 - val_loss: 0.6938 - val_accuracy: 0.6222
# Epoch 47/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.7158 - val_loss: 0.6689 - val_accuracy: 0.7333
# Epoch 48/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6281 - accuracy: 0.8526 - val_loss: 0.6554 - val_accuracy: 0.7333
# Epoch 49/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6019 - accuracy: 0.8105 - val_loss: 0.6528 - val_accuracy: 0.6444
# Epoch 50/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6100 - accuracy: 0.7789 - val_loss: 0.6327 - val_accuracy: 0.7333
# Epoch 51/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5698 - accuracy: 0.8421 - val_loss: 0.6218 - val_accuracy: 0.7333
# Epoch 52/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5703 - accuracy: 0.8421 - val_loss: 0.6095 - val_accuracy: 0.7333
# Epoch 53/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5836 - accuracy: 0.8105 - val_loss: 0.5897 - val_accuracy: 0.7778
# Epoch 54/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5360 - accuracy: 0.8632 - val_loss: 0.5879 - val_accuracy: 0.7333
# Epoch 55/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5386 - accuracy: 0.8211 - val_loss: 0.5732 - val_accuracy: 0.7778
# Epoch 56/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5264 - accuracy: 0.8400 - val_loss: 0.5594 - val_accuracy: 0.7778
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5215 - accuracy: 0.9158 - val_loss: 0.5378 - val_accuracy: 0.9111
# Epoch 58/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5155 - accuracy: 0.9053 - val_loss: 0.5358 - val_accuracy: 0.8444
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4930 - accuracy: 0.8737 - val_loss: 0.5391 - val_accuracy: 0.7778
# Epoch 60/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4960 - accuracy: 0.8632 - val_loss: 0.5336 - val_accuracy: 0.7778
# Epoch 61/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4677 - accuracy: 0.8737 - val_loss: 0.4972 - val_accuracy: 0.9111
# Epoch 62/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4739 - accuracy: 0.9684 - val_loss: 0.4971 - val_accuracy: 0.9111
# Epoch 63/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4741 - accuracy: 0.8947 - val_loss: 0.4984 - val_accuracy: 0.8444
# Epoch 64/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4671 - accuracy: 0.9263 - val_loss: 0.4959 - val_accuracy: 0.8444
# Epoch 65/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4580 - accuracy: 0.9053 - val_loss: 0.4828 - val_accuracy: 0.8889
# Epoch 66/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4401 - accuracy: 0.9158 - val_loss: 0.4731 - val_accuracy: 0.9111
# Epoch 67/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4476 - accuracy: 0.9000 - val_loss: 0.4714 - val_accuracy: 0.9111
# Epoch 68/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4295 - accuracy: 0.9263 - val_loss: 0.4621 - val_accuracy: 0.9111
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4398 - accuracy: 0.9474 - val_loss: 0.4512 - val_accuracy: 0.9111
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3945 - accuracy: 0.9579 - val_loss: 0.4473 - val_accuracy: 0.9111
# Epoch 71/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4361 - accuracy: 0.9368 - val_loss: 0.4468 - val_accuracy: 0.9111
# Epoch 72/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4034 - accuracy: 0.9263 - val_loss: 0.4342 - val_accuracy: 0.9111
# Epoch 73/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4097 - accuracy: 0.9684 - val_loss: 0.4279 - val_accuracy: 0.9111
# Epoch 74/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4191 - accuracy: 0.9368 - val_loss: 0.4240 - val_accuracy: 0.9111
# Epoch 75/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.9474 - val_loss: 0.4198 - val_accuracy: 0.9111
# Epoch 76/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3726 - accuracy: 0.9579 - val_loss: 0.4269 - val_accuracy: 0.9111
# Epoch 77/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3987 - accuracy: 0.9474 - val_loss: 0.4031 - val_accuracy: 0.9333
# Epoch 78/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3875 - accuracy: 0.9500 - val_loss: 0.4230 - val_accuracy: 0.9111
# Epoch 79/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3915 - accuracy: 0.9368 - val_loss: 0.4080 - val_accuracy: 0.9111
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.9684 - val_loss: 0.3954 - val_accuracy: 0.9111
# Epoch 81/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3748 - accuracy: 0.9368 - val_loss: 0.3879 - val_accuracy: 0.9333
# Epoch 82/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.9684 - val_loss: 0.3830 - val_accuracy: 0.9333
# Epoch 83/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3728 - accuracy: 0.9474 - val_loss: 0.3907 - val_accuracy: 0.9111
# Epoch 84/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3604 - accuracy: 0.9474 - val_loss: 0.3802 - val_accuracy: 0.9333
# Epoch 85/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3815 - accuracy: 0.9368 - val_loss: 0.3733 - val_accuracy: 0.9333
# Epoch 86/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3413 - accuracy: 0.9684 - val_loss: 0.3773 - val_accuracy: 0.9333
# Epoch 87/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.9368 - val_loss: 0.3786 - val_accuracy: 0.9111
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.9579 - val_loss: 0.3807 - val_accuracy: 0.9111
# Epoch 89/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3342 - accuracy: 0.9600 - val_loss: 0.3614 - val_accuracy: 0.9333
# Epoch 90/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3490 - accuracy: 0.9368 - val_loss: 0.3446 - val_accuracy: 0.9778
# Epoch 91/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3355 - accuracy: 0.9579 - val_loss: 0.3568 - val_accuracy: 0.9333
# Epoch 92/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3336 - accuracy: 0.9684 - val_loss: 0.3562 - val_accuracy: 0.9333
# Epoch 93/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3159 - accuracy: 0.9579 - val_loss: 0.3461 - val_accuracy: 0.9333
# Epoch 94/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3404 - accuracy: 0.9684 - val_loss: 0.3378 - val_accuracy: 0.9556
# Epoch 95/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3153 - accuracy: 0.9579 - val_loss: 0.3422 - val_accuracy: 0.9333
# Epoch 96/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3194 - accuracy: 0.9474 - val_loss: 0.3377 - val_accuracy: 0.9333
# Epoch 97/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3238 - accuracy: 0.9579 - val_loss: 0.3267 - val_accuracy: 0.9778
# Epoch 98/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3130 - accuracy: 0.9684 - val_loss: 0.3345 - val_accuracy: 0.9333
# Epoch 99/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3283 - accuracy: 0.9474 - val_loss: 0.3431 - val_accuracy: 0.9333
# Epoch 100/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3126 - accuracy: 0.9500 - val_loss: 0.3263 - val_accuracy: 0.9333
# Epoch 101/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.9579 - val_loss: 0.3084 - val_accuracy: 0.9556
# Epoch 102/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3058 - accuracy: 0.9368 - val_loss: 0.3186 - val_accuracy: 0.9778
# Epoch 103/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3156 - accuracy: 0.9579 - val_loss: 0.3431 - val_accuracy: 0.9333
# Epoch 104/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3006 - accuracy: 0.9474 - val_loss: 0.3181 - val_accuracy: 0.9333
# Epoch 105/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2853 - accuracy: 0.9684 - val_loss: 0.3032 - val_accuracy: 0.9778
# Epoch 106/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2888 - accuracy: 0.9684 - val_loss: 0.3057 - val_accuracy: 0.9778
# Epoch 107/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.9579 - val_loss: 0.3087 - val_accuracy: 0.9778
# Epoch 108/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3309 - accuracy: 0.9474 - val_loss: 0.3048 - val_accuracy: 0.9778
# Epoch 109/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2587 - accuracy: 0.9789 - val_loss: 0.3014 - val_accuracy: 0.9778
# Epoch 110/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.9474 - val_loss: 0.3085 - val_accuracy: 0.9333
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2761 - accuracy: 0.9600 - val_loss: 0.2870 - val_accuracy: 0.9778
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2981 - accuracy: 0.9368 - val_loss: 0.2919 - val_accuracy: 0.9778
# Epoch 113/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.9684 - val_loss: 0.2925 - val_accuracy: 0.9778
# Epoch 114/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.9579 - val_loss: 0.2813 - val_accuracy: 0.9778
# Epoch 115/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.9789 - val_loss: 0.2861 - val_accuracy: 0.9778
# Epoch 116/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2808 - accuracy: 0.9579 - val_loss: 0.2855 - val_accuracy: 0.9778
# Epoch 117/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2829 - accuracy: 0.9368 - val_loss: 0.2786 - val_accuracy: 0.9778
# Epoch 118/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2528 - accuracy: 0.9789 - val_loss: 0.2964 - val_accuracy: 0.9333
# Epoch 119/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2828 - accuracy: 0.9474 - val_loss: 0.2919 - val_accuracy: 0.9333
# Epoch 120/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.9368 - val_loss: 0.2765 - val_accuracy: 0.9778
# Epoch 121/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2642 - accuracy: 0.9474 - val_loss: 0.2696 - val_accuracy: 0.9778
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.9600 - val_loss: 0.2775 - val_accuracy: 0.9778
# Epoch 123/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.9579 - val_loss: 0.2790 - val_accuracy: 0.9778
# Epoch 124/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2413 - accuracy: 0.9789 - val_loss: 0.2696 - val_accuracy: 0.9778
# Epoch 125/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2912 - accuracy: 0.9368 - val_loss: 0.2603 - val_accuracy: 0.9778
# Epoch 126/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.9474 - val_loss: 0.2712 - val_accuracy: 0.9778
# Epoch 127/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9895 - val_loss: 0.2774 - val_accuracy: 0.9778
# Epoch 128/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.9368 - val_loss: 0.2522 - val_accuracy: 0.9556
# Epoch 129/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2565 - accuracy: 0.9579 - val_loss: 0.2631 - val_accuracy: 0.9778
# Epoch 130/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2505 - accuracy: 0.9684 - val_loss: 0.2757 - val_accuracy: 0.9778
# Epoch 131/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.9579 - val_loss: 0.2637 - val_accuracy: 0.9778
# Epoch 132/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2493 - accuracy: 0.9579 - val_loss: 0.2550 - val_accuracy: 0.9778
# Epoch 133/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2541 - accuracy: 0.9400 - val_loss: 0.2501 - val_accuracy: 0.9778
# Epoch 134/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2476 - accuracy: 0.9579 - val_loss: 0.2580 - val_accuracy: 0.9778
# Epoch 135/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2356 - accuracy: 0.9684 - val_loss: 0.2617 - val_accuracy: 0.9778
# Epoch 136/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.9579 - val_loss: 0.2466 - val_accuracy: 0.9778
# Epoch 137/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2462 - accuracy: 0.9474 - val_loss: 0.2452 - val_accuracy: 0.9778
# Epoch 138/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2636 - accuracy: 0.9579 - val_loss: 0.2539 - val_accuracy: 0.9778
# Epoch 139/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1955 - accuracy: 0.9895 - val_loss: 0.2486 - val_accuracy: 0.9778
# Epoch 140/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2597 - accuracy: 0.9579 - val_loss: 0.2493 - val_accuracy: 0.9778
# Epoch 141/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.9579 - val_loss: 0.2460 - val_accuracy: 0.9778
# Epoch 142/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.9579 - val_loss: 0.2393 - val_accuracy: 0.9778
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2435 - accuracy: 0.9579 - val_loss: 0.2429 - val_accuracy: 0.9778
# Epoch 144/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2419 - accuracy: 0.9600 - val_loss: 0.2406 - val_accuracy: 0.9778
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2312 - accuracy: 0.9684 - val_loss: 0.2440 - val_accuracy: 0.9778
# Epoch 146/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2519 - accuracy: 0.9579 - val_loss: 0.2429 - val_accuracy: 0.9778
# Epoch 147/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1904 - accuracy: 0.9789 - val_loss: 0.2391 - val_accuracy: 0.9778
# Epoch 148/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2606 - accuracy: 0.9579 - val_loss: 0.2398 - val_accuracy: 0.9778
# Epoch 149/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.9474 - val_loss: 0.2262 - val_accuracy: 0.9556
# Epoch 150/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2235 - accuracy: 0.9474 - val_loss: 0.2327 - val_accuracy: 0.9778
# Epoch 151/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2175 - accuracy: 0.9684 - val_loss: 0.2442 - val_accuracy: 0.9778
# Epoch 152/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2357 - accuracy: 0.9579 - val_loss: 0.2325 - val_accuracy: 0.9778
# Epoch 153/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.9579 - val_loss: 0.2277 - val_accuracy: 0.9778
# Epoch 154/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2237 - accuracy: 0.9579 - val_loss: 0.2271 - val_accuracy: 0.9778
# Epoch 155/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.9500 - val_loss: 0.2254 - val_accuracy: 0.9778
# Epoch 156/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2353 - accuracy: 0.9579 - val_loss: 0.2344 - val_accuracy: 0.9778
# Epoch 157/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2415 - accuracy: 0.9579 - val_loss: 0.2237 - val_accuracy: 0.9778
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2069 - accuracy: 0.9684 - val_loss: 0.2371 - val_accuracy: 0.9778
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2003 - accuracy: 0.9895 - val_loss: 0.2351 - val_accuracy: 0.9778
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2371 - accuracy: 0.9368 - val_loss: 0.2173 - val_accuracy: 0.9778
# Epoch 161/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2313 - accuracy: 0.9474 - val_loss: 0.2217 - val_accuracy: 0.9778
# Epoch 162/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1994 - accuracy: 0.9684 - val_loss: 0.2311 - val_accuracy: 0.9778
# Epoch 163/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2440 - accuracy: 0.9579 - val_loss: 0.2235 - val_accuracy: 0.9778
# Epoch 164/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.9474 - val_loss: 0.2206 - val_accuracy: 0.9778
# Epoch 165/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9579 - val_loss: 0.2156 - val_accuracy: 0.9778
# Epoch 166/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2200 - accuracy: 0.9600 - val_loss: 0.2217 - val_accuracy: 0.9778
# Epoch 167/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2352 - accuracy: 0.9579 - val_loss: 0.2252 - val_accuracy: 0.9778
# Epoch 168/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9579 - val_loss: 0.2131 - val_accuracy: 0.9778
# Epoch 169/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1945 - accuracy: 0.9579 - val_loss: 0.2147 - val_accuracy: 0.9778
# Epoch 170/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2194 - accuracy: 0.9684 - val_loss: 0.2175 - val_accuracy: 0.9778
# Epoch 171/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2167 - accuracy: 0.9579 - val_loss: 0.2201 - val_accuracy: 0.9778
# Epoch 172/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2097 - accuracy: 0.9579 - val_loss: 0.2158 - val_accuracy: 0.9778
# Epoch 173/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9684 - val_loss: 0.2157 - val_accuracy: 0.9778
# Epoch 174/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2302 - accuracy: 0.9579 - val_loss: 0.2131 - val_accuracy: 0.9778
# Epoch 175/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2152 - accuracy: 0.9474 - val_loss: 0.2089 - val_accuracy: 0.9778
# Epoch 176/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.9579 - val_loss: 0.2071 - val_accuracy: 0.9778
# Epoch 177/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2175 - accuracy: 0.9600 - val_loss: 0.2139 - val_accuracy: 0.9778
# Epoch 178/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1965 - accuracy: 0.9789 - val_loss: 0.2119 - val_accuracy: 0.9778
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2370 - accuracy: 0.9368 - val_loss: 0.2037 - val_accuracy: 0.9778
# Epoch 180/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2159 - accuracy: 0.9579 - val_loss: 0.2275 - val_accuracy: 0.9778
# Epoch 181/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2200 - accuracy: 0.9474 - val_loss: 0.2094 - val_accuracy: 0.9778
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2008 - accuracy: 0.9579 - val_loss: 0.2046 - val_accuracy: 0.9778
# Epoch 183/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1837 - accuracy: 0.9789 - val_loss: 0.2099 - val_accuracy: 0.9778
# Epoch 184/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.9474 - val_loss: 0.2067 - val_accuracy: 0.9778
# Epoch 185/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2215 - accuracy: 0.9368 - val_loss: 0.2034 - val_accuracy: 0.9778
# Epoch 186/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1842 - accuracy: 0.9789 - val_loss: 0.2073 - val_accuracy: 0.9778
# Epoch 187/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2106 - accuracy: 0.9579 - val_loss: 0.2086 - val_accuracy: 0.9778
# Epoch 188/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2076 - accuracy: 0.9600 - val_loss: 0.2004 - val_accuracy: 0.9778
# Epoch 189/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1843 - accuracy: 0.9684 - val_loss: 0.1998 - val_accuracy: 0.9778
# Epoch 190/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.9368 - val_loss: 0.2025 - val_accuracy: 0.9778
# Epoch 191/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2201 - accuracy: 0.9579 - val_loss: 0.2021 - val_accuracy: 0.9778
# Epoch 192/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1757 - accuracy: 0.9789 - val_loss: 0.2078 - val_accuracy: 0.9778
# Epoch 193/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2333 - accuracy: 0.9474 - val_loss: 0.2055 - val_accuracy: 0.9778
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2057 - accuracy: 0.9579 - val_loss: 0.1992 - val_accuracy: 0.9778
# Epoch 195/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2160 - accuracy: 0.9474 - val_loss: 0.1999 - val_accuracy: 0.9778
# Epoch 196/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1950 - accuracy: 0.9579 - val_loss: 0.1978 - val_accuracy: 0.9778
# Epoch 197/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1789 - accuracy: 0.9684 - val_loss: 0.2008 - val_accuracy: 0.9778
# Epoch 198/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2042 - accuracy: 0.9579 - val_loss: 0.1974 - val_accuracy: 0.9778
# Epoch 199/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2030 - accuracy: 0.9600 - val_loss: 0.1954 - val_accuracy: 0.9778
# Epoch 200/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2016 - accuracy: 0.9579 - val_loss: 0.1977 - val_accuracy: 0.9778

# %% [markdown]
# ## 결과 확인

# %%
hist_view(hist)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# ## training loss and acc ##
# Test loss: 0.1976756602525711
# Test accuracy: 0.9777777791023254

# %%
model.layers[2].weights
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(4, 4) dtype=float32, numpy=
#  array([[ 5.9066963e-01,  4.8696485e-01,  2.2225671e-01, -5.1473959e-05],
#         [ 1.4420216e+00, -5.8669075e-02,  8.7331343e-01, -2.3807836e-05],
#         [-2.4134756e-04,  4.6836980e-05,  5.7182428e-05, -3.5576231e-05],
#         [-2.0427890e-01,  8.9981747e-01, -6.3905489e-01, -1.9825875e-06]],
#        dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(4,) dtype=float32, numpy=array([-0.14761232,  0.74518454, -0.34382242, -0.02062097], dtype=float32)>]

# %%
decoder = {k:v for k,v in enumerate( sets )}
decoder
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
r=np.argmax(model.predict(x_test[:10,:]), axis=-1)
[decoder[i] for i in r]
# Out:
# ['virginica',
#  'versicolor',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'versicolor',
#  'versicolor',
#  'versicolor']

# %% [markdown]
# # 시각화도 하고 만든 모델도 저장하고 만든 모델에 대한 평가도 하고, 하고 싶은 것이 많지만, 다음 장에서...==^^==
