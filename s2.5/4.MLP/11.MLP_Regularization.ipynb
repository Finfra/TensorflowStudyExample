# %% [markdown]
# # 11. Regularization 적용해 보기
# * [딥러닝 용어 정리, L1 Regularization, L2 Regularization 의 이해, 용도와 차이 설명](https://light-tree.tistory.com/125)
# ---
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile4.uf.tistory.com%2Fimage%2F99BED3425CE4B1341814F6)

# %%
batch_size = 10
num_classes = 3
epochs = 200

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import optimizers

import matplotlib.pyplot as plt
def hist_view(hist):
  print('## training loss and acc ##')
  fig, loss_ax = plt.subplots()
  acc_ax = loss_ax.twinx()

  loss_ax.plot(hist.history['loss'], 'y', label='train loss')
  loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

  loss_ax.set_xlabel('epoch')
  loss_ax.set_ylabel('loss')
  loss_ax.legend(loc='center')

  acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
  acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
  acc_ax.set_ylabel('accuracy')
  acc_ax.legend(loc='center right')

  plt.show()

# %%
# from sklearn import datasets
# iris = datasets.load_iris()
# x=iris.data
import pandas as pd
![ ! -f  iris0.csv ]&&wget http://j.finfra.com/_file/iris0.csv
iris=pd.read_csv("iris0.csv")
# Out:
# --2021-02-01 00:53:56--  http://j.finfra.com/_file/iris0.csv
# Resolving j.finfra.com (j.finfra.com)... 211.252.85.187
# Connecting to j.finfra.com (j.finfra.com)|211.252.85.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3730 (3.6K) [text/csv]
# Saving to: ‘iris0.csv’
#
# iris0.csv           100%[===================>]   3.64K  --.-KB/s    in 0s
#
# 2021-02-01 00:53:56 (124 MB/s) - ‘iris0.csv’ saved [3730/3730]

# %%
x=iris.iloc[:,0:4].values
y_text=iris.iloc[:,4:5]

sets=y_text.drop_duplicates()["Species"].tolist()
encoder={k:v for v,k in enumerate(sets)}
y_num=[ encoder[i] for i in y_text["Species"].tolist() ]

# %%
# iris.target → y
y= keras.utils.to_categorical(y_num, num_classes)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((105, 4), (45, 4), (105, 3), (45, 3))

# %%
from keras.layers import BatchNormalization, Dropout
from keras import regularizers

l2=regularizers.l2(l2=0.01)

model = Sequential()

model.add(Dense(6, activation='relu', input_shape=(4,)))
model.add(Dense(4, activation='relu',kernel_regularizer=l2))

model.add(Dense(4, activation='relu',kernel_regularizer='l1'))

model.add(Dense(num_classes, activation='softmax'))
model.summary()

adam=optimizers.Adam(0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# batch_size,epochs
spe=int(x_train.shape[0]/batch_size )
hist=model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          steps_per_epoch=spe,
          validation_data=(x_test, y_test))

# help(model.fit)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 6)                 30
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 28
# _________________________________________________________________
# dense_26 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_27 (Dense)             (None, 3)                 15
# =================================================================
# Total params: 93
# Trainable params: 93
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 10/10 [==============================] - 1s 23ms/step - loss: 2.0281 - accuracy: 0.2953 - val_loss: 1.7161 - val_accuracy: 0.3556
# Epoch 2/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.8280 - accuracy: 0.3172 - val_loss: 1.5882 - val_accuracy: 0.3556
# Epoch 3/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.6244 - accuracy: 0.3059 - val_loss: 1.4900 - val_accuracy: 0.3556
# Epoch 4/200
# 10/10 [==============================] - 0s 21ms/step - loss: 1.4366 - accuracy: 0.4191 - val_loss: 1.4166 - val_accuracy: 0.3556
# Epoch 5/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4992 - accuracy: 0.2685 - val_loss: 1.3610 - val_accuracy: 0.3556
# Epoch 6/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4269 - accuracy: 0.2910 - val_loss: 1.3191 - val_accuracy: 0.3556
# Epoch 7/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3415 - accuracy: 0.3823 - val_loss: 1.2896 - val_accuracy: 0.3556
# Epoch 8/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3615 - accuracy: 0.2589 - val_loss: 1.2665 - val_accuracy: 0.3556
# Epoch 9/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2725 - accuracy: 0.3620 - val_loss: 1.2502 - val_accuracy: 0.3556
# Epoch 10/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2794 - accuracy: 0.3162 - val_loss: 1.2389 - val_accuracy: 0.3556
# Epoch 11/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2761 - accuracy: 0.3027 - val_loss: 1.2298 - val_accuracy: 0.3556
# Epoch 12/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2546 - accuracy: 0.3300 - val_loss: 1.2228 - val_accuracy: 0.2667
# Epoch 13/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2499 - accuracy: 0.1253 - val_loss: 1.2153 - val_accuracy: 0.0667
# Epoch 14/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2331 - accuracy: 0.0191 - val_loss: 1.2103 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2210 - accuracy: 0.0389 - val_loss: 1.2054 - val_accuracy: 0.0222
# Epoch 16/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2177 - accuracy: 0.0762 - val_loss: 1.2018 - val_accuracy: 0.0889
# Epoch 17/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2047 - accuracy: 0.1770 - val_loss: 1.1984 - val_accuracy: 0.2667
# Epoch 18/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2052 - accuracy: 0.1913 - val_loss: 1.1954 - val_accuracy: 0.4000
# Epoch 19/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1919 - accuracy: 0.3389 - val_loss: 1.1924 - val_accuracy: 0.2444
# Epoch 20/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2047 - accuracy: 0.1396 - val_loss: 1.1898 - val_accuracy: 0.2444
# Epoch 21/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1904 - accuracy: 0.3593 - val_loss: 1.1875 - val_accuracy: 0.2444
# Epoch 22/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1894 - accuracy: 0.3429 - val_loss: 1.1849 - val_accuracy: 0.2444
# Epoch 23/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1745 - accuracy: 0.3665 - val_loss: 1.1826 - val_accuracy: 0.2444
# Epoch 24/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1669 - accuracy: 0.3723 - val_loss: 1.1805 - val_accuracy: 0.2444
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1787 - accuracy: 0.3702 - val_loss: 1.1787 - val_accuracy: 0.2444
# Epoch 26/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1883 - accuracy: 0.3429 - val_loss: 1.1774 - val_accuracy: 0.2444
# Epoch 27/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1791 - accuracy: 0.2740 - val_loss: 1.1754 - val_accuracy: 0.2444
# Epoch 28/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1395 - accuracy: 0.4950 - val_loss: 1.1741 - val_accuracy: 0.2444
# Epoch 29/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1544 - accuracy: 0.3667 - val_loss: 1.1725 - val_accuracy: 0.2444
# Epoch 30/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1613 - accuracy: 0.3670 - val_loss: 1.1709 - val_accuracy: 0.2444
# Epoch 31/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1526 - accuracy: 0.3741 - val_loss: 1.1695 - val_accuracy: 0.2444
# Epoch 32/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1291 - accuracy: 0.3849 - val_loss: 1.1676 - val_accuracy: 0.2444
# Epoch 33/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1520 - accuracy: 0.3329 - val_loss: 1.1662 - val_accuracy: 0.2444
# Epoch 34/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1336 - accuracy: 0.3792 - val_loss: 1.1652 - val_accuracy: 0.2444
# Epoch 35/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1496 - accuracy: 0.3366 - val_loss: 1.1635 - val_accuracy: 0.2444
# Epoch 36/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1636 - accuracy: 0.2845 - val_loss: 1.1618 - val_accuracy: 0.2444
# Epoch 37/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1231 - accuracy: 0.3865 - val_loss: 1.1602 - val_accuracy: 0.2444
# Epoch 38/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1209 - accuracy: 0.3877 - val_loss: 1.1586 - val_accuracy: 0.2444
# Epoch 39/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1145 - accuracy: 0.3978 - val_loss: 1.1567 - val_accuracy: 0.2444
# Epoch 40/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1199 - accuracy: 0.3928 - val_loss: 1.1547 - val_accuracy: 0.2444
# Epoch 41/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0902 - accuracy: 0.4023 - val_loss: 1.1530 - val_accuracy: 0.2444
# Epoch 42/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.3577 - val_loss: 1.1513 - val_accuracy: 0.2444
# Epoch 43/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1106 - accuracy: 0.3617 - val_loss: 1.1491 - val_accuracy: 0.2444
# Epoch 44/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0832 - accuracy: 0.4424 - val_loss: 1.1474 - val_accuracy: 0.2444
# Epoch 45/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3799 - val_loss: 1.1454 - val_accuracy: 0.2444
# Epoch 46/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1266 - accuracy: 0.2904 - val_loss: 1.1428 - val_accuracy: 0.2444
# Epoch 47/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0961 - accuracy: 0.3734 - val_loss: 1.1406 - val_accuracy: 0.2444
# Epoch 48/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0795 - accuracy: 0.4148 - val_loss: 1.1391 - val_accuracy: 0.2444
# Epoch 49/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1171 - accuracy: 0.3327 - val_loss: 1.1365 - val_accuracy: 0.2444
# Epoch 50/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0778 - accuracy: 0.3757 - val_loss: 1.1339 - val_accuracy: 0.2444
# Epoch 51/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0718 - accuracy: 0.4050 - val_loss: 1.1315 - val_accuracy: 0.2444
# Epoch 52/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0863 - accuracy: 0.3700 - val_loss: 1.1290 - val_accuracy: 0.2444
# Epoch 53/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0784 - accuracy: 0.3687 - val_loss: 1.1265 - val_accuracy: 0.2444
# Epoch 54/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0805 - accuracy: 0.3594 - val_loss: 1.1231 - val_accuracy: 0.2444
# Epoch 55/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1091 - accuracy: 0.3049 - val_loss: 1.1187 - val_accuracy: 0.2444
# Epoch 56/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0537 - accuracy: 0.3988 - val_loss: 1.1153 - val_accuracy: 0.2444
# Epoch 57/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0507 - accuracy: 0.4166 - val_loss: 1.1111 - val_accuracy: 0.2444
# Epoch 58/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0912 - accuracy: 0.2960 - val_loss: 1.1038 - val_accuracy: 0.2444
# Epoch 59/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0574 - accuracy: 0.3810 - val_loss: 1.0992 - val_accuracy: 0.2444
# Epoch 60/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0503 - accuracy: 0.3579 - val_loss: 1.0941 - val_accuracy: 0.2444
# Epoch 61/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0245 - accuracy: 0.3949 - val_loss: 1.0884 - val_accuracy: 0.2444
# Epoch 62/200
# 10/10 [==============================] - 0s 18ms/step - loss: 1.0337 - accuracy: 0.3796 - val_loss: 1.0813 - val_accuracy: 0.2444
# Epoch 63/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0173 - accuracy: 0.3779 - val_loss: 1.0751 - val_accuracy: 0.2444
# Epoch 64/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0140 - accuracy: 0.3724 - val_loss: 1.0691 - val_accuracy: 0.2444
# Epoch 65/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0373 - accuracy: 0.3165 - val_loss: 1.0588 - val_accuracy: 0.2889
# Epoch 66/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9952 - accuracy: 0.4121 - val_loss: 1.0515 - val_accuracy: 0.2889
# Epoch 67/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9918 - accuracy: 0.4287 - val_loss: 1.0415 - val_accuracy: 0.3333
# Epoch 68/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9686 - accuracy: 0.5356 - val_loss: 1.0342 - val_accuracy: 0.3556
# Epoch 69/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0192 - accuracy: 0.3681 - val_loss: 1.0212 - val_accuracy: 0.4667
# Epoch 70/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9565 - accuracy: 0.6590 - val_loss: 1.0097 - val_accuracy: 0.5556
# Epoch 71/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9107 - accuracy: 0.7342 - val_loss: 1.0010 - val_accuracy: 0.5556
# Epoch 72/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9587 - accuracy: 0.6270 - val_loss: 0.9870 - val_accuracy: 0.6000
# Epoch 73/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9239 - accuracy: 0.6464 - val_loss: 0.9740 - val_accuracy: 0.6000
# Epoch 74/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9375 - accuracy: 0.6140 - val_loss: 0.9592 - val_accuracy: 0.6000
# Epoch 75/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9086 - accuracy: 0.6927 - val_loss: 0.9428 - val_accuracy: 0.6000
# Epoch 76/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8430 - accuracy: 0.7542 - val_loss: 0.9247 - val_accuracy: 0.6000
# Epoch 77/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8513 - accuracy: 0.7300 - val_loss: 0.9052 - val_accuracy: 0.6000
# Epoch 78/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8359 - accuracy: 0.7030 - val_loss: 0.8811 - val_accuracy: 0.6000
# Epoch 79/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8280 - accuracy: 0.6727 - val_loss: 0.8567 - val_accuracy: 0.6000
# Epoch 80/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8366 - accuracy: 0.5927 - val_loss: 0.8313 - val_accuracy: 0.6000
# Epoch 81/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7467 - accuracy: 0.7305 - val_loss: 0.8126 - val_accuracy: 0.6000
# Epoch 82/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7677 - accuracy: 0.6791 - val_loss: 0.7884 - val_accuracy: 0.6000
# Epoch 83/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7087 - accuracy: 0.7245 - val_loss: 0.7678 - val_accuracy: 0.6000
# Epoch 84/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6948 - accuracy: 0.7339 - val_loss: 0.7529 - val_accuracy: 0.6000
# Epoch 85/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.6753 - val_loss: 0.7348 - val_accuracy: 0.6000
# Epoch 86/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6820 - accuracy: 0.6918 - val_loss: 0.7178 - val_accuracy: 0.6000
# Epoch 87/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6571 - accuracy: 0.7098 - val_loss: 0.7046 - val_accuracy: 0.6000
# Epoch 88/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7047 - accuracy: 0.6348 - val_loss: 0.6925 - val_accuracy: 0.6000
# Epoch 89/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6593 - accuracy: 0.6567 - val_loss: 0.6782 - val_accuracy: 0.6222
# Epoch 90/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6135 - accuracy: 0.7303 - val_loss: 0.6705 - val_accuracy: 0.6222
# Epoch 91/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5891 - accuracy: 0.7877 - val_loss: 0.6591 - val_accuracy: 0.6222
# Epoch 92/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5938 - accuracy: 0.7476 - val_loss: 0.6545 - val_accuracy: 0.6222
# Epoch 93/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5862 - accuracy: 0.7295 - val_loss: 0.6409 - val_accuracy: 0.6222
# Epoch 94/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6103 - accuracy: 0.6516 - val_loss: 0.6269 - val_accuracy: 0.6222
# Epoch 95/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5710 - accuracy: 0.7440 - val_loss: 0.6206 - val_accuracy: 0.6222
# Epoch 96/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5606 - accuracy: 0.7695 - val_loss: 0.6178 - val_accuracy: 0.6222
# Epoch 97/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5661 - accuracy: 0.7094 - val_loss: 0.6050 - val_accuracy: 0.6222
# Epoch 98/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.6894 - val_loss: 0.5949 - val_accuracy: 0.6222
# Epoch 99/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5803 - accuracy: 0.6700 - val_loss: 0.5905 - val_accuracy: 0.6222
# Epoch 100/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5754 - accuracy: 0.7206 - val_loss: 0.5813 - val_accuracy: 0.6444
# Epoch 101/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5350 - accuracy: 0.7571 - val_loss: 0.5822 - val_accuracy: 0.6222
# Epoch 102/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5614 - accuracy: 0.6586 - val_loss: 0.5681 - val_accuracy: 0.6444
# Epoch 103/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5218 - accuracy: 0.7333 - val_loss: 0.5676 - val_accuracy: 0.6222
# Epoch 104/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5065 - accuracy: 0.7612 - val_loss: 0.5608 - val_accuracy: 0.6444
# Epoch 105/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4800 - accuracy: 0.8053 - val_loss: 0.5495 - val_accuracy: 0.6444
# Epoch 106/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4605 - accuracy: 0.8508 - val_loss: 0.5408 - val_accuracy: 0.6889
# Epoch 107/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4967 - accuracy: 0.8795 - val_loss: 0.5436 - val_accuracy: 0.6444
# Epoch 108/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5097 - accuracy: 0.7942 - val_loss: 0.5404 - val_accuracy: 0.6444
# Epoch 109/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4788 - accuracy: 0.8082 - val_loss: 0.5333 - val_accuracy: 0.6444
# Epoch 110/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5256 - accuracy: 0.7398 - val_loss: 0.5189 - val_accuracy: 0.7333
# Epoch 111/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5045 - accuracy: 0.8083 - val_loss: 0.5198 - val_accuracy: 0.6889
# Epoch 112/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5080 - accuracy: 0.8136 - val_loss: 0.5258 - val_accuracy: 0.6444
# Epoch 113/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5190 - accuracy: 0.6986 - val_loss: 0.5107 - val_accuracy: 0.7111
# Epoch 114/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4980 - accuracy: 0.8721 - val_loss: 0.5029 - val_accuracy: 0.7333
# Epoch 115/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4473 - accuracy: 0.8938 - val_loss: 0.5043 - val_accuracy: 0.7111
# Epoch 116/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4080 - accuracy: 0.9020 - val_loss: 0.5016 - val_accuracy: 0.7111
# Epoch 117/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4814 - accuracy: 0.8250 - val_loss: 0.4981 - val_accuracy: 0.7111
# Epoch 118/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4566 - accuracy: 0.8728 - val_loss: 0.4954 - val_accuracy: 0.7111
# Epoch 119/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4253 - accuracy: 0.8473 - val_loss: 0.4893 - val_accuracy: 0.7333
# Epoch 120/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4473 - accuracy: 0.8678 - val_loss: 0.4819 - val_accuracy: 0.8000
# Epoch 121/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4454 - accuracy: 0.8762 - val_loss: 0.4803 - val_accuracy: 0.8000
# Epoch 122/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4717 - accuracy: 0.8491 - val_loss: 0.4762 - val_accuracy: 0.8000
# Epoch 123/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3905 - accuracy: 0.9256 - val_loss: 0.4775 - val_accuracy: 0.7333
# Epoch 124/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4356 - accuracy: 0.7967 - val_loss: 0.4584 - val_accuracy: 0.8667
# Epoch 125/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4311 - accuracy: 0.9183 - val_loss: 0.4559 - val_accuracy: 0.8667
# Epoch 126/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4151 - accuracy: 0.9119 - val_loss: 0.4594 - val_accuracy: 0.8222
# Epoch 127/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4227 - accuracy: 0.9078 - val_loss: 0.4533 - val_accuracy: 0.8444
# Epoch 128/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4115 - accuracy: 0.9079 - val_loss: 0.4586 - val_accuracy: 0.8222
# Epoch 129/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3821 - accuracy: 0.8725 - val_loss: 0.4488 - val_accuracy: 0.8444
# Epoch 130/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4147 - accuracy: 0.9143 - val_loss: 0.4366 - val_accuracy: 0.8889
# Epoch 131/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4371 - accuracy: 0.8748 - val_loss: 0.4348 - val_accuracy: 0.8889
# Epoch 132/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3853 - accuracy: 0.9206 - val_loss: 0.4412 - val_accuracy: 0.8444
# Epoch 133/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3764 - accuracy: 0.9236 - val_loss: 0.4373 - val_accuracy: 0.8444
# Epoch 134/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3819 - accuracy: 0.9073 - val_loss: 0.4332 - val_accuracy: 0.8667
# Epoch 135/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4066 - accuracy: 0.8885 - val_loss: 0.4151 - val_accuracy: 0.9333
# Epoch 136/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4097 - accuracy: 0.8853 - val_loss: 0.4238 - val_accuracy: 0.8667
# Epoch 137/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3968 - accuracy: 0.9040 - val_loss: 0.4214 - val_accuracy: 0.8667
# Epoch 138/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3767 - accuracy: 0.9175 - val_loss: 0.4160 - val_accuracy: 0.8889
# Epoch 139/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3831 - accuracy: 0.9562 - val_loss: 0.4184 - val_accuracy: 0.8667
# Epoch 140/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3606 - accuracy: 0.9244 - val_loss: 0.4037 - val_accuracy: 0.9111
# Epoch 141/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3590 - accuracy: 0.9574 - val_loss: 0.3979 - val_accuracy: 0.9333
# Epoch 142/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3355 - accuracy: 0.9624 - val_loss: 0.4080 - val_accuracy: 0.8889
# Epoch 143/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3673 - accuracy: 0.8997 - val_loss: 0.4028 - val_accuracy: 0.8889
# Epoch 144/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3470 - accuracy: 0.9167 - val_loss: 0.3951 - val_accuracy: 0.9111
# Epoch 145/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3129 - accuracy: 0.9658 - val_loss: 0.3904 - val_accuracy: 0.9111
# Epoch 146/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3939 - accuracy: 0.8790 - val_loss: 0.3824 - val_accuracy: 0.9556
# Epoch 147/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3448 - accuracy: 0.9642 - val_loss: 0.4031 - val_accuracy: 0.8667
# Epoch 148/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3389 - accuracy: 0.9212 - val_loss: 0.3965 - val_accuracy: 0.8889
# Epoch 149/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3389 - accuracy: 0.9363 - val_loss: 0.3675 - val_accuracy: 0.9778
# Epoch 150/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3673 - accuracy: 0.9562 - val_loss: 0.3785 - val_accuracy: 0.9333
# Epoch 151/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2996 - accuracy: 0.9480 - val_loss: 0.3960 - val_accuracy: 0.8667
# Epoch 152/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3619 - accuracy: 0.9206 - val_loss: 0.3775 - val_accuracy: 0.9111
# Epoch 153/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3333 - accuracy: 0.9162 - val_loss: 0.3732 - val_accuracy: 0.9111
# Epoch 154/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3133 - accuracy: 0.9420 - val_loss: 0.3672 - val_accuracy: 0.9333
# Epoch 155/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3020 - accuracy: 0.9563 - val_loss: 0.3734 - val_accuracy: 0.9111
# Epoch 156/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3736 - accuracy: 0.8850 - val_loss: 0.3556 - val_accuracy: 0.9556
# Epoch 157/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3093 - accuracy: 0.9773 - val_loss: 0.3682 - val_accuracy: 0.9111
# Epoch 158/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3443 - accuracy: 0.9247 - val_loss: 0.3535 - val_accuracy: 0.9556
# Epoch 159/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2730 - accuracy: 0.9883 - val_loss: 0.3500 - val_accuracy: 0.9556
# Epoch 160/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2917 - accuracy: 0.9623 - val_loss: 0.3612 - val_accuracy: 0.9111
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3212 - accuracy: 0.9217 - val_loss: 0.3572 - val_accuracy: 0.9333
# Epoch 162/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2983 - accuracy: 0.9300 - val_loss: 0.3421 - val_accuracy: 0.9556
# Epoch 163/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2984 - accuracy: 0.9604 - val_loss: 0.3357 - val_accuracy: 0.9778
# Epoch 164/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3155 - accuracy: 0.9279 - val_loss: 0.3511 - val_accuracy: 0.9333
# Epoch 165/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3212 - accuracy: 0.9206 - val_loss: 0.3350 - val_accuracy: 0.9556
# Epoch 166/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2922 - accuracy: 0.9584 - val_loss: 0.3475 - val_accuracy: 0.9333
# Epoch 167/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3106 - accuracy: 0.9661 - val_loss: 0.3250 - val_accuracy: 0.9778
# Epoch 168/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3062 - accuracy: 0.9264 - val_loss: 0.3429 - val_accuracy: 0.9333
# Epoch 169/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3058 - accuracy: 0.9027 - val_loss: 0.3417 - val_accuracy: 0.9333
# Epoch 170/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2935 - accuracy: 0.9444 - val_loss: 0.3405 - val_accuracy: 0.9333
# Epoch 171/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2850 - accuracy: 0.9604 - val_loss: 0.3276 - val_accuracy: 0.9556
# Epoch 172/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2975 - accuracy: 0.9285 - val_loss: 0.3156 - val_accuracy: 0.9778
# Epoch 173/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3189 - accuracy: 0.9139 - val_loss: 0.3218 - val_accuracy: 0.9556
# Epoch 174/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2868 - accuracy: 0.9593 - val_loss: 0.3214 - val_accuracy: 0.9556
# Epoch 175/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2686 - accuracy: 0.9584 - val_loss: 0.3239 - val_accuracy: 0.9556
# Epoch 176/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3312 - accuracy: 0.9113 - val_loss: 0.3272 - val_accuracy: 0.9333
# Epoch 177/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2702 - accuracy: 0.9521 - val_loss: 0.3115 - val_accuracy: 0.9556
# Epoch 178/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2794 - accuracy: 0.9422 - val_loss: 0.3105 - val_accuracy: 0.9556
# Epoch 179/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2317 - accuracy: 0.9630 - val_loss: 0.3217 - val_accuracy: 0.9333
# Epoch 180/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2677 - accuracy: 0.9596 - val_loss: 0.3010 - val_accuracy: 0.9778
# Epoch 181/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2779 - accuracy: 0.9439 - val_loss: 0.3034 - val_accuracy: 0.9556
# Epoch 182/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2652 - accuracy: 0.9524 - val_loss: 0.3033 - val_accuracy: 0.9556
# Epoch 183/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2168 - accuracy: 0.9888 - val_loss: 0.3107 - val_accuracy: 0.9556
# Epoch 184/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2815 - accuracy: 0.9275 - val_loss: 0.3042 - val_accuracy: 0.9556
# Epoch 185/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2552 - accuracy: 0.9322 - val_loss: 0.2931 - val_accuracy: 0.9778
# Epoch 186/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2616 - accuracy: 0.9603 - val_loss: 0.2955 - val_accuracy: 0.9556
# Epoch 187/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2821 - accuracy: 0.9329 - val_loss: 0.2952 - val_accuracy: 0.9556
# Epoch 188/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2495 - accuracy: 0.9494 - val_loss: 0.3070 - val_accuracy: 0.9556
# Epoch 189/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2868 - accuracy: 0.9303 - val_loss: 0.2870 - val_accuracy: 0.9778
# Epoch 190/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2738 - accuracy: 0.9499 - val_loss: 0.2792 - val_accuracy: 0.9778
# Epoch 191/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2103 - accuracy: 0.9928 - val_loss: 0.2871 - val_accuracy: 0.9778
# Epoch 192/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2630 - accuracy: 0.9495 - val_loss: 0.2948 - val_accuracy: 0.9556
# Epoch 193/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2495 - accuracy: 0.9642 - val_loss: 0.2757 - val_accuracy: 0.9778
# Epoch 194/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2053 - accuracy: 0.9856 - val_loss: 0.2772 - val_accuracy: 0.9778
# Epoch 195/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2697 - accuracy: 0.9571 - val_loss: 0.2846 - val_accuracy: 0.9556
# Epoch 196/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2404 - accuracy: 0.9638 - val_loss: 0.2775 - val_accuracy: 0.9778
# Epoch 197/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2233 - accuracy: 0.9766 - val_loss: 0.2783 - val_accuracy: 0.9778
# Epoch 198/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2587 - accuracy: 0.9346 - val_loss: 0.2789 - val_accuracy: 0.9556
# Epoch 199/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2418 - accuracy: 0.9599 - val_loss: 0.2729 - val_accuracy: 0.9778
# Epoch 200/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2093 - accuracy: 0.9784 - val_loss: 0.2679 - val_accuracy: 0.9778

# %%
hist_view(hist)
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# ## training loss and acc ##
# Test loss: 0.18172912299633026
# Test accuracy: 0.9777777791023254

# %%
model.layers[2].weights
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(4, 4) dtype=float32, numpy=
#  array([[ 9.6140558e-01,  9.9074614e-01,  3.7640005e-01,  1.5415442e-02],
#         [-6.8937698e-03, -3.9451796e-01,  2.7958056e-01, -4.4919940e-04],
#         [ 2.8010818e-05,  5.6163489e-04,  8.3072897e-05, -3.0145733e-05],
#         [-3.7990028e-01, -2.8850916e-01, -1.5486424e-01,  1.0264015e+00]],
#        dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(4,) dtype=float32, numpy=array([ 0.26680925,  0.21182968, -0.07025702, -0.2859159 ], dtype=float32)>]

# %%
decoder = {k:v for k,v in enumerate( sets )}
decoder
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
r=np.argmax(model.predict(x_test[:10,:]), axis=-1)
[decoder[i] for i in r]
# Out:
# ['virginica',
#  'versicolor',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'versicolor',
#  'versicolor',
#  'versicolor']

# %% [markdown]
# # 시각화도 하고 만든 모델도 저장하고 만든 모델에 대한 평가도 하고, 하고 싶은 것이 많지만, 다음 장에서...==^^==
