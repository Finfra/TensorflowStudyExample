# %% [markdown]
# # 3. Train데이터와 Test데이터 분리

# %% [markdown]
# ## library
# 최소한으로 필요한 라이브러리들 선언

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## 데이터 셋 불러오기
# iris 데이터

# %%
from sklearn import datasets
iris = datasets.load_iris()
x=iris.data
y= keras.utils.to_categorical(iris.target, 3)

# %% [markdown]
# ## 훈련, 평가 데이터셋 분리
# sklearn 에서 지원해주는 train_test_split 함수를 이용하여 훈련 데이터와 평가  데이터를 분리해준다.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((105, 4), (45, 4), (105, 3), (45, 3))

# %% [markdown]
# ## 모델 구성
# 간단하게 모델 구성하기

# %%
model = Sequential()
model.add(Dense(5, activation='relu', input_shape=(4,)))
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 25
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 18
# =================================================================
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 사용할 fuction 들을 지정

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Validation
# 훈련 데이터로 학습을 하고, 평가데이터를 validation data 로 넣어서 모델이 잘 예측하는지 평가하여 Overfitting 을 막아준다.

# %%
model.fit(x_train, y_train,
          batch_size=10,
          epochs=100,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 17ms/step - loss: 1.4869 - accuracy: 0.1048 - val_loss: 1.5908 - val_accuracy: 0.1111
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.3740 - accuracy: 0.0857 - val_loss: 1.4411 - val_accuracy: 0.1333
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2770 - accuracy: 0.2571 - val_loss: 1.3155 - val_accuracy: 0.2000
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.2049 - accuracy: 0.3524 - val_loss: 1.2095 - val_accuracy: 0.5333
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1486 - accuracy: 0.6000 - val_loss: 1.1301 - val_accuracy: 0.6000
# Epoch 6/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1127 - accuracy: 0.5714 - val_loss: 1.0742 - val_accuracy: 0.6444
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0933 - accuracy: 0.5333 - val_loss: 1.0283 - val_accuracy: 0.6000
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0760 - accuracy: 0.5048 - val_loss: 1.0081 - val_accuracy: 0.6222
# Epoch 9/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0658 - accuracy: 0.5619 - val_loss: 0.9927 - val_accuracy: 0.6444
# Epoch 10/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0569 - accuracy: 0.5619 - val_loss: 0.9859 - val_accuracy: 0.6444
# Epoch 11/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0465 - accuracy: 0.5619 - val_loss: 0.9715 - val_accuracy: 0.6444
# Epoch 12/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.0398 - accuracy: 0.5619 - val_loss: 0.9531 - val_accuracy: 0.6222
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0334 - accuracy: 0.5333 - val_loss: 0.9393 - val_accuracy: 0.6222
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0229 - accuracy: 0.5810 - val_loss: 0.9445 - val_accuracy: 0.6444
# Epoch 15/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0144 - accuracy: 0.5714 - val_loss: 0.9399 - val_accuracy: 0.6444
# Epoch 16/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.0062 - accuracy: 0.5714 - val_loss: 0.9267 - val_accuracy: 0.6222
# Epoch 17/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.9991 - accuracy: 0.5619 - val_loss: 0.9160 - val_accuracy: 0.6222
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9917 - accuracy: 0.5524 - val_loss: 0.9078 - val_accuracy: 0.6444
# Epoch 19/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9843 - accuracy: 0.5619 - val_loss: 0.9029 - val_accuracy: 0.6222
# Epoch 20/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9772 - accuracy: 0.5714 - val_loss: 0.8976 - val_accuracy: 0.6222
# Epoch 21/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9706 - accuracy: 0.5714 - val_loss: 0.8941 - val_accuracy: 0.6444
# Epoch 22/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9640 - accuracy: 0.5619 - val_loss: 0.8924 - val_accuracy: 0.6444
# Epoch 23/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9575 - accuracy: 0.5619 - val_loss: 0.8855 - val_accuracy: 0.6444
# Epoch 24/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9510 - accuracy: 0.5714 - val_loss: 0.8779 - val_accuracy: 0.6444
# Epoch 25/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9448 - accuracy: 0.5619 - val_loss: 0.8697 - val_accuracy: 0.6444
# Epoch 26/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9398 - accuracy: 0.5619 - val_loss: 0.8689 - val_accuracy: 0.6444
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9332 - accuracy: 0.5810 - val_loss: 0.8550 - val_accuracy: 0.6222
# Epoch 28/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9267 - accuracy: 0.5714 - val_loss: 0.8517 - val_accuracy: 0.6444
# Epoch 29/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9204 - accuracy: 0.5619 - val_loss: 0.8489 - val_accuracy: 0.6444
# Epoch 30/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.9164 - accuracy: 0.5619 - val_loss: 0.8393 - val_accuracy: 0.6444
# Epoch 31/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9093 - accuracy: 0.5714 - val_loss: 0.8376 - val_accuracy: 0.6444
# Epoch 32/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9033 - accuracy: 0.5714 - val_loss: 0.8319 - val_accuracy: 0.6444
# Epoch 33/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9007 - accuracy: 0.5619 - val_loss: 0.8201 - val_accuracy: 0.6444
# Epoch 34/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8936 - accuracy: 0.5714 - val_loss: 0.8244 - val_accuracy: 0.6444
# Epoch 35/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8872 - accuracy: 0.5619 - val_loss: 0.8221 - val_accuracy: 0.6222
# Epoch 36/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8812 - accuracy: 0.5619 - val_loss: 0.8169 - val_accuracy: 0.6222
# Epoch 37/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8763 - accuracy: 0.5619 - val_loss: 0.8125 - val_accuracy: 0.6222
# Epoch 38/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.8714 - accuracy: 0.5619 - val_loss: 0.8062 - val_accuracy: 0.6222
# Epoch 39/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8661 - accuracy: 0.5619 - val_loss: 0.8042 - val_accuracy: 0.6222
# Epoch 40/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8611 - accuracy: 0.5619 - val_loss: 0.7960 - val_accuracy: 0.6222
# Epoch 41/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8558 - accuracy: 0.5619 - val_loss: 0.7962 - val_accuracy: 0.6222
# Epoch 42/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8507 - accuracy: 0.5619 - val_loss: 0.7910 - val_accuracy: 0.6222
# Epoch 43/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8454 - accuracy: 0.5810 - val_loss: 0.7857 - val_accuracy: 0.6222
# Epoch 44/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8409 - accuracy: 0.5714 - val_loss: 0.7797 - val_accuracy: 0.6222
# Epoch 45/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8360 - accuracy: 0.5619 - val_loss: 0.7785 - val_accuracy: 0.6000
# Epoch 46/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8304 - accuracy: 0.5619 - val_loss: 0.7718 - val_accuracy: 0.6222
# Epoch 47/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8260 - accuracy: 0.5619 - val_loss: 0.7660 - val_accuracy: 0.6222
# Epoch 48/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8210 - accuracy: 0.5619 - val_loss: 0.7638 - val_accuracy: 0.6000
# Epoch 49/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8162 - accuracy: 0.5619 - val_loss: 0.7591 - val_accuracy: 0.6000
# Epoch 50/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8115 - accuracy: 0.5619 - val_loss: 0.7561 - val_accuracy: 0.6000
# Epoch 51/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.8069 - accuracy: 0.5429 - val_loss: 0.7587 - val_accuracy: 0.6222
# Epoch 52/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8026 - accuracy: 0.5524 - val_loss: 0.7547 - val_accuracy: 0.6222
# Epoch 53/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7981 - accuracy: 0.5524 - val_loss: 0.7509 - val_accuracy: 0.6222
# Epoch 54/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7935 - accuracy: 0.5429 - val_loss: 0.7409 - val_accuracy: 0.6222
# Epoch 55/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7883 - accuracy: 0.5238 - val_loss: 0.7372 - val_accuracy: 0.6222
# Epoch 56/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7841 - accuracy: 0.5333 - val_loss: 0.7379 - val_accuracy: 0.6222
# Epoch 57/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7802 - accuracy: 0.5333 - val_loss: 0.7272 - val_accuracy: 0.6222
# Epoch 58/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7755 - accuracy: 0.5238 - val_loss: 0.7262 - val_accuracy: 0.6222
# Epoch 59/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7710 - accuracy: 0.5238 - val_loss: 0.7177 - val_accuracy: 0.6222
# Epoch 60/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7664 - accuracy: 0.5429 - val_loss: 0.7192 - val_accuracy: 0.6222
# Epoch 61/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7616 - accuracy: 0.5524 - val_loss: 0.7151 - val_accuracy: 0.6222
# Epoch 62/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7579 - accuracy: 0.5524 - val_loss: 0.7127 - val_accuracy: 0.6222
# Epoch 63/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7532 - accuracy: 0.5524 - val_loss: 0.7100 - val_accuracy: 0.6222
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7490 - accuracy: 0.5524 - val_loss: 0.7032 - val_accuracy: 0.6222
# Epoch 65/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7454 - accuracy: 0.5429 - val_loss: 0.6973 - val_accuracy: 0.6222
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7414 - accuracy: 0.5333 - val_loss: 0.6933 - val_accuracy: 0.6222
# Epoch 67/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7374 - accuracy: 0.5429 - val_loss: 0.6912 - val_accuracy: 0.6222
# Epoch 68/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7328 - accuracy: 0.5333 - val_loss: 0.6848 - val_accuracy: 0.6222
# Epoch 69/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7290 - accuracy: 0.5429 - val_loss: 0.6831 - val_accuracy: 0.6222
# Epoch 70/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7252 - accuracy: 0.5429 - val_loss: 0.6835 - val_accuracy: 0.6222
# Epoch 71/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7219 - accuracy: 0.5429 - val_loss: 0.6850 - val_accuracy: 0.6222
# Epoch 72/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7168 - accuracy: 0.5429 - val_loss: 0.6794 - val_accuracy: 0.6222
# Epoch 73/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7132 - accuracy: 0.5429 - val_loss: 0.6747 - val_accuracy: 0.6222
# Epoch 74/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7107 - accuracy: 0.5524 - val_loss: 0.6675 - val_accuracy: 0.6222
# Epoch 75/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7057 - accuracy: 0.5524 - val_loss: 0.6661 - val_accuracy: 0.6000
# Epoch 76/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7019 - accuracy: 0.5524 - val_loss: 0.6634 - val_accuracy: 0.6000
# Epoch 77/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6985 - accuracy: 0.5429 - val_loss: 0.6610 - val_accuracy: 0.6222
# Epoch 78/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6948 - accuracy: 0.5429 - val_loss: 0.6617 - val_accuracy: 0.6222
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6911 - accuracy: 0.5429 - val_loss: 0.6578 - val_accuracy: 0.6222
# Epoch 80/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.5429 - val_loss: 0.6550 - val_accuracy: 0.6222
# Epoch 81/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6839 - accuracy: 0.5619 - val_loss: 0.6569 - val_accuracy: 0.6222
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5714 - val_loss: 0.6506 - val_accuracy: 0.6222
# Epoch 83/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6771 - accuracy: 0.5714 - val_loss: 0.6485 - val_accuracy: 0.6222
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6741 - accuracy: 0.6000 - val_loss: 0.6478 - val_accuracy: 0.6000
# Epoch 85/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6709 - accuracy: 0.5810 - val_loss: 0.6414 - val_accuracy: 0.6222
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6667 - accuracy: 0.5714 - val_loss: 0.6411 - val_accuracy: 0.6000
# Epoch 87/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6638 - accuracy: 0.5905 - val_loss: 0.6371 - val_accuracy: 0.6222
# Epoch 88/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6605 - accuracy: 0.5905 - val_loss: 0.6346 - val_accuracy: 0.6222
# Epoch 89/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6580 - accuracy: 0.5905 - val_loss: 0.6319 - val_accuracy: 0.6000
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6544 - accuracy: 0.5905 - val_loss: 0.6287 - val_accuracy: 0.6000
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6511 - accuracy: 0.5905 - val_loss: 0.6253 - val_accuracy: 0.6222
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6487 - accuracy: 0.6000 - val_loss: 0.6262 - val_accuracy: 0.6000
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6453 - accuracy: 0.6190 - val_loss: 0.6251 - val_accuracy: 0.6000
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6426 - accuracy: 0.6286 - val_loss: 0.6232 - val_accuracy: 0.6000
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6395 - accuracy: 0.6286 - val_loss: 0.6191 - val_accuracy: 0.6000
# Epoch 96/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6362 - accuracy: 0.6381 - val_loss: 0.6169 - val_accuracy: 0.6000
# Epoch 97/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6338 - accuracy: 0.6381 - val_loss: 0.6130 - val_accuracy: 0.6000
# Epoch 98/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6305 - accuracy: 0.6286 - val_loss: 0.6119 - val_accuracy: 0.6000
# Epoch 99/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6281 - accuracy: 0.6381 - val_loss: 0.6138 - val_accuracy: 0.6000
# Epoch 100/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6254 - accuracy: 0.6381 - val_loss: 0.6122 - val_accuracy: 0.6000

# %% [markdown]
# ## Score 확인

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.612221896648407
# Test accuracy: 0.6000000238418579

# %% [markdown]
# ## Decoder 를 통한 predict

# %%
decoder = {k:v for k,v in enumerate( iris.target_names )}

# %%
r=np.argmax(model.predict(x_test[:10,:]), axis=-1)
[decoder[i] for i in r]
# Out:
# ['virginica',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'virginica',
#  'virginica']

# %% [markdown]
# # 모델의 Training되는 과정을 Text로 보기 때문에 한눈에 잘 안 들어옴.
